# %%
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import keras.utils as ku 
import numpy as np

# %%
tokenizer = Tokenizer()

# %%
def dataset_preparation(data):

    # basic cleanup
    corpus = data.lower().split("\n")

    # tokenization	
    tokenizer.fit_on_texts(corpus)
    total_words = len(tokenizer.word_index) + 1

    # create input sequences using list of tokens
    input_sequences = []
    for line in corpus:
        token_list = tokenizer.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
            
    # pad sequences 
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

    # create predictors and label
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = ku.to_categorical(label, num_classes=total_words)

    return predictors, label, max_sequence_len, total_words

# %%
def create_model(predictors, label, max_sequence_len, total_words):

    model = Sequential()
    model.add(Embedding(total_words, 10, input_length=max_sequence_len-1))
    model.add(LSTM(150, return_sequences = True))
    # model.add(Dropout(0.2))
    model.add(LSTM(100))
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
    model.fit(predictors, label, epochs=100, verbose=1, callbacks=[earlystop])
    print (model.summary())
    return model

# %%
def generate_text(seed_text, next_words, max_sequence_len, model):
    for j in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen= 
                             max_sequence_len-1, padding='pre')
        predicted = model.predict_classes(token_list, verbose=0)
  
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %%
def generate_text(seed_text, next_words, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict_classes(token_list, verbose=0)

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %%
data = open('data.txt').read()

# %%
predictors, label, max_sequence_len, total_words = dataset_preparation(data)
model = create_model(predictors, label, max_sequence_len, total_words)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 1s 14ms/step - loss: 3.7618 - accuracy: 0.0208
# Epoch 2/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7579 - accuracy: 0.0625
# Epoch 3/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7553 - accuracy: 0.0833
# Epoch 4/100
# 48/48 [==============================] - 0s 958us/step - loss: 3.7520 - accuracy: 0.0625
# Epoch 5/100
# 32/48 [===================>..........] - ETA: 0s - loss: 3.7509 - accuracy: 0.0938
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7473 - accuracy: 0.0833
# Epoch 6/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7426 - accuracy: 0.0833
# Epoch 7/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7364 - accuracy: 0.0833
# Epoch 8/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7257 - accuracy: 0.0625
# Epoch 9/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.7132 - accuracy: 0.0625
# Epoch 10/100
# 48/48 [==============================] - 0s 976us/step - loss: 3.6952 - accuracy: 0.0625
# Epoch 11/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.6677 - accuracy: 0.0625
# Epoch 12/100
# 48/48 [==============================] - 0s 973us/step - loss: 3.6490 - accuracy: 0.0625
# Epoch 13/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.6319 - accuracy: 0.0625
# Epoch 14/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.6187 - accuracy: 0.0625
# Epoch 15/100
# 48/48 [==============================] - 0s 2ms/step - loss: 3.6210 - accuracy: 0.0625
# Epoch 16/100
# 48/48 [==============================] - 0s 983us/step - loss: 3.6139 - accuracy: 0.0625
# Epoch 17/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5992 - accuracy: 0.0625
# Epoch 18/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5927 - accuracy: 0.0625
# Epoch 19/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5843 - accuracy: 0.0625
# Epoch 20/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5855 - accuracy: 0.0625
# Epoch 21/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5829 - accuracy: 0.0625
# Epoch 22/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5768 - accuracy: 0.0833
# Epoch 23/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5702 - accuracy: 0.0833
# Epoch 24/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5605 - accuracy: 0.1250
# Epoch 25/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5576 - accuracy: 0.0833
# Epoch 26/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5443 - accuracy: 0.0625
# Epoch 27/100
# 48/48 [==============================] - 0s 2ms/step - loss: 3.5383 - accuracy: 0.0625
# Epoch 28/100
# 48/48 [==============================] - 0s 912us/step - loss: 3.5308 - accuracy: 0.0833
# Epoch 29/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.5193 - accuracy: 0.1042
# Epoch 30/100
# 48/48 [==============================] - 0s 957us/step - loss: 3.5033 - accuracy: 0.1042
# Epoch 31/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.4943 - accuracy: 0.1250
# Epoch 32/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.4715 - accuracy: 0.1042
# Epoch 33/100
# 48/48 [==============================] - 0s 971us/step - loss: 3.4526 - accuracy: 0.1042
# Epoch 34/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.4306 - accuracy: 0.0833
# Epoch 35/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.3952 - accuracy: 0.1042
# Epoch 36/100
# 48/48 [==============================] - 0s 2ms/step - loss: 3.3598 - accuracy: 0.1250
# Epoch 37/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.3232 - accuracy: 0.1250
# Epoch 38/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.2768 - accuracy: 0.1042
# Epoch 39/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.2473 - accuracy: 0.1250
# Epoch 40/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.1954 - accuracy: 0.1458
# Epoch 41/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.1663 - accuracy: 0.1042
# Epoch 42/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.1366 - accuracy: 0.1042
# Epoch 43/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.1203 - accuracy: 0.1042
# Epoch 44/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.0987 - accuracy: 0.1250
# Epoch 45/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.0379 - accuracy: 0.1458
# Epoch 46/100
# 48/48 [==============================] - 0s 1ms/step - loss: 3.0026 - accuracy: 0.1667
# Epoch 47/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.9931 - accuracy: 0.1667
# Epoch 48/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.9408 - accuracy: 0.1667
# Epoch 49/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.8981 - accuracy: 0.1875
# Epoch 50/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.8779 - accuracy: 0.1667
# Epoch 51/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.8385 - accuracy: 0.1875
# Epoch 52/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.8059 - accuracy: 0.2083
# Epoch 53/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.7664 - accuracy: 0.2083
# Epoch 54/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.7250 - accuracy: 0.2292
# Epoch 55/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.6955 - accuracy: 0.2292
# Epoch 56/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.6625 - accuracy: 0.2292
# Epoch 57/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.6256 - accuracy: 0.2292
# Epoch 58/100
# 48/48 [==============================] - 0s 977us/step - loss: 2.5843 - accuracy: 0.2500
# Epoch 59/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.5647 - accuracy: 0.3125
# Epoch 60/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.5192 - accuracy: 0.2500
# Epoch 61/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.5051 - accuracy: 0.2917
# Epoch 62/100
# 48/48 [==============================] - 0s 998us/step - loss: 2.4632 - accuracy: 0.2917
# Epoch 63/100
# 48/48 [==============================] - 0s 929us/step - loss: 2.4531 - accuracy: 0.3750
# Epoch 64/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.4072 - accuracy: 0.3125
# Epoch 65/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.4553 - accuracy: 0.3542
# Epoch 66/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.3684 - accuracy: 0.3333
# Epoch 67/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.3194 - accuracy: 0.3542
# Epoch 68/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.2931 - accuracy: 0.3958
# Epoch 69/100
# 48/48 [==============================] - 0s 824us/step - loss: 2.2659 - accuracy: 0.3958
# Epoch 70/100
# 48/48 [==============================] - 0s 922us/step - loss: 2.2637 - accuracy: 0.3542
# Epoch 71/100
# 48/48 [==============================] - 0s 915us/step - loss: 2.2182 - accuracy: 0.4375
# Epoch 72/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.1933 - accuracy: 0.3750
# Epoch 73/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.1627 - accuracy: 0.4375
# Epoch 74/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.1323 - accuracy: 0.4792
# Epoch 75/100
# 48/48 [==============================] - 0s 918us/step - loss: 2.1634 - accuracy: 0.4167
# Epoch 76/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.0942 - accuracy: 0.4167
# Epoch 77/100
# 48/48 [==============================] - 0s 1ms/step - loss: 2.0771 - accuracy: 0.4375
# Epoch 78/100
# 48/48 [==============================] - 0s 960us/step - loss: 2.0366 - accuracy: 0.4792
# Epoch 79/100
# 48/48 [==============================] - 0s 924us/step - loss: 2.0132 - accuracy: 0.4583
# Epoch 80/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.9913 - accuracy: 0.4375
# Epoch 81/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.9911 - accuracy: 0.4792
# Epoch 82/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.9318 - accuracy: 0.4792
# Epoch 83/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.9067 - accuracy: 0.5000
# Epoch 84/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.9010 - accuracy: 0.5000
# Epoch 85/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.8579 - accuracy: 0.5000
# Epoch 86/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.8337 - accuracy: 0.5208
# Epoch 87/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.8452 - accuracy: 0.5000
# Epoch 88/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.8097 - accuracy: 0.5208
# Epoch 89/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.8021 - accuracy: 0.4792
# Epoch 90/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.7936 - accuracy: 0.5417
# Epoch 91/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.7804 - accuracy: 0.5208
# Epoch 92/100
# 48/48 [==============================] - 0s 939us/step - loss: 1.7385 - accuracy: 0.5000
# Epoch 93/100
# 48/48 [==============================] - 0s 949us/step - loss: 1.7263 - accuracy: 0.5833
# Epoch 94/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.7269 - accuracy: 0.5000
# Epoch 95/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.7549 - accuracy: 0.4792
# Epoch 96/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.6891 - accuracy: 0.5208
# Epoch 97/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.6905 - accuracy: 0.5000
# Epoch 98/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.6711 - accuracy: 0.5208
# Epoch 99/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.6495 - accuracy: 0.5417
# Epoch 100/100
# 48/48 [==============================] - 0s 1ms/step - loss: 1.5933 - accuracy: 0.5833
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 7, 10)             430
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 7, 150)            96600
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 100)               100400
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                4343
# =================================================================
# Total params: 201,773
# Trainable params: 201,773
# Non-trainable params: 0
# _________________________________________________________________
# None
# we naughty lost their to

# %%
print (generate_text("Tea is", 3, max_sequence_len))
# Out:
# Tea is we lost their
